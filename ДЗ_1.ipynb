# %%
# Как обычно, для начала подгружаем нужные нам пакеты
import pandas as pd    # пакет для работы с таблицами 
import numpy as np     # пакет для работы с матрицами 

# пакеты для картиночек 
import matplotlib

import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')  # правильный (наиболее красивый) стиль у графиков

# %matplotlib inline

# %%
# загрузка файлов

ratings = pd.read_csv("ratings.csv")
tags= pd.read_csv("tags.csv")
movies = pd.read_csv("movies.csv")

# %%
movies
# Out:
#         movieId                                              title  \
# 0             1                                   Toy Story (1995)
# 1             1                                   Toy Story (1995)
# 2             1                                   Toy Story (1995)
# 3             1                                   Toy Story (1995)
# 4             1                                   Toy Story (1995)
# 5             1                                   Toy Story (1995)
# 6             1                                   Toy Story (1995)
# 7             1                                   Toy Story (1995)
# 8             1                                   Toy Story (1995)
# 9             1                                   Toy Story (1995)
# 10            1                                   Toy Story (1995)
# 11            1                                   Toy Story (1995)
# 12            1                                   Toy Story (1995)
# ...

# %%
ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# 5            1       70     3.0   964982400
# 6            1      101     5.0   964980868
# 7            1      110     4.0   964982176
# 8            1      151     5.0   964984041
# 9            1      157     5.0   964984100
# 10           1      163     5.0   964983650
# 11           1      216     5.0   964981208
# 12           1      223     3.0   964980985
# 13           1      231     5.0   964981179
# 14           1      235     4.0   964980908
# 15           1      260     5.0   964981680
# 16           1      296     3.0   964982967
# 17           1      316     3.0   964982310
# 18           1      333     5.0   964981179
# 19           1      349     4.0   964982563
# ...

# %%
tags
# Out:
#       userId  movieId                     tag   timestamp
# 0          2    60756                   funny  1445714994
# 1          2    60756         Highly quotable  1445714996
# 2          2    60756            will ferrell  1445714992
# 3          2    89774            Boxing story  1445715207
# 4          2    89774                     MMA  1445715200
# 5          2    89774               Tom Hardy  1445715205
# 6          2   106782                   drugs  1445715054
# 7          2   106782       Leonardo DiCaprio  1445715051
# 8          2   106782         Martin Scorsese  1445715056
# 9          7    48516            way too long  1169687325
# 10        18      431               Al Pacino  1462138765
# 11        18      431                gangster  1462138749
# 12        18      431                   mafia  1462138755
# 13        18     1221               Al Pacino  1461699306
# 14        18     1221                   Mafia  1461699303
# ...

# %%
#соединяем 2 файла при помощи merge
movies = movies.merge(ratings, on = 'movieId', how = 'inner')
movies
# Out:
#         movieId                                              title  \
# 0             1                                   Toy Story (1995)
# 1             1                                   Toy Story (1995)
# 2             1                                   Toy Story (1995)
# 3             1                                   Toy Story (1995)
# 4             1                                   Toy Story (1995)
# 5             1                                   Toy Story (1995)
# 6             1                                   Toy Story (1995)
# 7             1                                   Toy Story (1995)
# 8             1                                   Toy Story (1995)
# 9             1                                   Toy Story (1995)
# 10            1                                   Toy Story (1995)
# 11            1                                   Toy Story (1995)
# 12            1                                   Toy Story (1995)
# ...

# %%
#количество пользователей
users_ = list(np.sort(df.userId.unique()))
len(users_)
# Out:
# 610

# %%
#количество фильмов 
movies_ = list(np.sort(df.movieId.unique()))
len(movies_)
# Out:
# 9724

# %%
#создаем файл для дальнейшей работы SVD модели
movies = movies[['userId','movieId','rating']]
movies
# Out:
#         userId  movieId  rating
# 0            1        1     4.0
# 1            5        1     4.0
# 2            7        1     4.5
# 3           15        1     2.5
# 4           17        1     4.5
# 5           18        1     3.5
# 6           19        1     4.0
# 7           21        1     3.5
# 8           27        1     3.0
# 9           31        1     5.0
# 10          32        1     3.0
# 11          33        1     3.0
# 12          40        1     5.0
# 13          43        1     5.0
# 14          44        1     3.0
# 15          45        1     4.0
# 16          46        1     5.0
# 17          50        1     3.0
# 18          54        1     3.0
# 19          57        1     5.0
# 20          63        1     5.0
# 21          64        1     4.0
# 22          66        1     4.0
# 23          68        1     2.5
# 24          71        1     5.0
# 25          73        1     4.5
# 26          76        1     0.5
# 27          78        1     4.0
# ...

# %%
#количество оценок всех пользователей на все фильмы
len(movies)
# Out:
# 100836

# %%
#Импортируем нужные нам пакеты данных
from surprise import SVD
from surprise import Dataset, Reader
from surprise.model_selection import cross_validate

# %%
#Создаем Риддер,который созадет рамки для нашей SVD модели 
reader=Reader(rating_scale=(1,5))

# %%
#Подгружаем датасет и запускаем алгоритм обучения модели на кросс валидации
data = Dataset.load_from_df(movies, reader)
algo = SVD()
cross_validate(algo, data, measures=['MSE'], cv=5, verbose=True)
# Out:
# Evaluating MSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# MSE (testset)     0.7551  0.7696  0.7682  0.7533  0.7720  0.7636  0.0078
# Fit time          5.89    6.04    5.97    5.64    5.78    5.87    0.14
# Test time         0.14    0.25    0.22    0.21    0.15    0.20    0.04
# {'test_mse': array([0.75511465, 0.76961327, 0.76819585, 0.75325188, 0.7719691 ]),
#  'fit_time': (5.893793821334839,
#   6.043318748474121,
#   5.9723803997039795,
#   5.63984489440918,
#   5.779261589050293),
#  'test_time': (0.1436164379119873,
#   0.248335599899292,
#   0.22240519523620605,
#   0.21443486213684082,
#   0.15204834938049316)}

# %% [markdown]
# Итоговое среднее MSE получилось: 0,76
# До этого мы пробовали также различные модели с источника:https://github.com/NicolasHug/Surprise. Но SVD c методом обучения кросс валидации предлагает наивысшее качество.
